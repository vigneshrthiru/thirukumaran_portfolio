# %%
#web scraper

# %%
from bs4 import BeautifulSoup
import requests

# %%
url='https://coinmarketcap.com/currencies/bitcoin/'

# %%
page=requests.get(url)

# %%
soup=BeautifulSoup(page.text,'html')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# ...

# %%
soup.find('span',class_='sc-65e7f566-0 lsTl')
# Out:
# <span class="sc-65e7f566-0 lsTl" data-role="coin-name" title="Bitcoin">Bitcoin<span class="sc-65e7f566-0 eQBACe coin-name-mobile"> price</span></span>

# %%
soup.find('span',class_='sc-65e7f566-0 lsTl').text
# Out:
# 'Bitcoin price'

# %%
crypto_name=soup.find('span',class_='sc-65e7f566-0 lsTl').text
print(crypto_name)
# Out:
# Bitcoin price

# %%
soup.find('span',class_='sc-65e7f566-0 eQBACe coin-name-mobile')
# Out:
# <span class="sc-65e7f566-0 eQBACe coin-name-mobile"> price</span>

# %%
soup.find('span',class_='sc-65e7f566-0 eQBACe coin-name-mobile').text
# Out:
# ' price'

# %%
crypto_price=soup.find('span',class_='sc-65e7f566-0 eQBACe coin-name-mobile').text
print(crypto_price)
# Out:
#  price

# %%
soup.find('span',class_='sc-65e7f566-0 WXGwg base-text')
# Out:
# <span class="sc-65e7f566-0 WXGwg base-text" data-test="text-cdp-price-display">$96,962.94</span>

# %%
soup.find('span',class_='sc-65e7f566-0 WXGwg base-text').text
# Out:
# '$96,962.94'

# %%
#sometimes u need to remove dollar sign when we export to other files we need a conversion so not to hesitate and remove the dollar sign

# %%
crypto_value=soup.find('span',class_='sc-65e7f566-0 WXGwg base-text').text
print(crypto_value)
# Out:
# $96,962.94

# %%
crypto_value.replace('$','')
# Out:
# '96,962.94'

# %%
#now let's get into a dataframe setup

# %%
import pandas as pd

# %%
dict={'Crypto_Name':crypto_name,
     'Price':crypto_value}

df=pd.DataFrame([dict])
df
# Out:
#      Crypto_Name       Price
# 0  Bitcoin price  $96,962.94

# %%
#always try to add a time stamp as the bitcoin values are changing time to time

# %%
from datetime import datetime
dt=datetime.now()
print(dt)
# Out:
# 2025-05-07 16:13:07.095747

# %%
dict={'Crypto_Name':crypto_name,
     'Price':crypto_value,
     'Timestamp':dt}

df=pd.DataFrame([dict])
df
# Out:
#      Crypto_Name       Price                  Timestamp
# 0  Bitcoin price  $96,962.94 2025-05-07 16:13:07.095747
